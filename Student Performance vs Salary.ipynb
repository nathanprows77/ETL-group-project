# %%
# Dependencies
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import CSVs
salary_file = "./resources/teacher-salary-2017.csv"
academic_file = "./resources/academic-performance-2017.csv"

# %%
# Convert CSVs to Dataframes
salary_df = pd.read_csv(salary_file)
academic_df = pd.read_csv(academic_file)

# %%
# Show initial salary DataFrame
salary_df
# Out:
#                     State 1969-70 1979-80 1989-90 1999-2000 2009-10 2015-16  \
# 0                Alabama    6,818  13,060  24,828    36,689  47,571  48,518
# 1                 Alaska   10,560  27,210  43,153    46,462  59,672  67,443
# 2                Arizona    8,711  15,054  29,402    36,902  46,952  47,218
# 3               Arkansas    6,307  12,299  22,352    33,386  46,700  48,218
# 4             California   10,315  18,020  37,998    47,680  68,203  77,179
# 5               Colorado    7,761  16,205  30,758    38,163  49,202  46,155
# 6            Connecticut    9,262  16,229  40,461    51,780  64,350  72,013
# 7               Delaware    9,015  16,148  33,377    44,435  57,080  59,960
# 8   District of Columbia   10,285  22,190  38,402    47,076  64,548  75,810
# 9                Florida    8,412  14,149  28,803    36,722  46,708  49,199
# 10               Georgia    7,276  13,853  28,006    41,023  53,112  54,190
# 11                Hawaii    9,453  19,920  32,047    40,578  55,063  57,431
# 12                 Idaho    6,890  13,611  23,861    35,547  46,283  46,122
# 13              Illinois    9,569  17,601  32,794    46,486  62,077  61,342
# 14               Indiana    8,833  15,599  30,902    41,850  49,986  50,715
# 15                  Iowa    8,355  15,203  26,747    35,678  49,626  54,416
# 16                Kansas    7,612  13,690  28,744    34,981  46,657  47,755
# 17              Kentucky    6,953  14,520  26,292    36,380  49,543  52,134
# 18             Louisiana    7,028  13,760  24,300    33,109  48,903  49,745
# 19                 Maine    7,572  13,071  26,881    35,561  46,106  50,498
# 20              Maryland    9,383  17,558  36,319    44,048  63,971  66,456
# 21         Massachusetts    8,764  17,253  34,712    46,580  69,273  76,981
# 22              Michigan    9,826  19,663  37,072    49,044  57,958  62,028
# 23             Minnesota    8,658  15,912  32,190    39,802  52,431  56,913
# 24           Mississippi    5,798  11,850  24,292    31,857  45,644  42,744
# 25              Missouri    7,799  13,682  27,094    35,656  45,317  47,957
# 26               Montana    7,606  14,537  25,081    32,121  45,759  51,034
# 27              Nebraska    7,375  13,516  25,522    33,237  46,227  51,386
# 28                Nevada    9,215  16,295  30,590    39,390  51,524  56,943
# 29         New Hampshire    7,771  13,017  28,986    37,734  51,443  56,616
# 30            New Jersey    9,130  17,161  35,676    52,015  65,130  69,330
# 31            New Mexico    7,796  14,887  24,756    32,554  46,258  47,163
# 32              New York   10,336  19,812  38,925    51,020  71,633  79,152
# 33        North Carolina    7,494  14,117  27,883    39,404  46,850  47,941
# 34          North Dakota    6,696  13,263  23,016    29,863  42,964  50,472
# 35                  Ohio    8,300  15,269  31,218    41,436  55,958  56,441
# 36              Oklahoma    6,882  13,107  23,070    31,298  47,691  45,276
# 37                Oregon    8,818  16,266  30,840    42,336  55,224  60,359
# 32  79,637    66,396    61,926    74,388      73,130    80,200    80,608
# 33  49,837    48,139    44,125    53,286      56,480    52,453    48,823
# 34  51,618    43,013    41,456    43,985      42,804    48,102    51,400
# 35  57,000    53,317    47,726    59,659      59,393    62,650    57,479
# 36  45,245    44,208    40,968    44,088      44,861    53,395    46,109
# 37  61,631    56,644    50,842    58,937      60,683    61,829    61,469
# 38  65,863    56,901    51,621    63,711      69,261    66,231    66,349
# 39  66,477    56,375    56,269    68,907      67,427    66,824    67,415
# 40  48,598    44,497    40,831    52,013      51,717    53,190    49,666
# 41  42,668    41,131    38,596    40,705      41,669    43,482    42,798
# 42  48,456    45,287    43,672    51,698      52,071    51,826    49,104
# 43  52,575    46,604    44,172    52,546      53,847    54,033    52,845
# 44  47,244    49,103    46,601    45,265      50,090    51,373    47,749
# 45  60,187    51,184    39,021    55,443      54,121    54,954    59,984
# 46  51,049    51,839    43,947    59,124      55,534    55,997    51,769
# 47  54,147    59,259    58,825    58,205      58,829    59,342    54,727
# 48  45,701    49,141    42,853    43,652      50,180    51,456    46,461
# 49  54,998    57,576    50,030    61,003      58,987    57,395    55,110
# 50  58,650    52,880    50,048    53,779      48,916    62,542    59,209
#
#    2016-17.1
# 0     48,868
# 1     68,138
# 2     47,403
# 3     48,616
# 4     78,711
# 5     46,506
# 6     72,561
# 7     60,214
# 8     76,131
# 9     49,407
# 10    54,602
# 11    57,674
# 12    47,504
# 13    61,602
# 14    50,554
# 15    55,443
# 16    47,984
# 17    52,339
# 18    50,000
# 19    51,077
# 20    66,961
# 21    77,804
# 22    62,200
# 23    57,346
# 24    42,925
# 25    48,293
# 26    51,422
# 27    52,338
# 28    57,376
# 29    57,253
# 30    69,623
# 31    47,500
# 32    79,637
# 33    49,837
# 34    51,618
# 35    57,000
# 36    45,245
# 37    61,631
# 38    65,863
# 39    66,477
# 40    48,598
# 41    42,668
# 42    48,456
# 43    52,575
# 44    47,244
# 45    60,187
# 46    51,049
# 47    54,147
# 48    45,701
# 49    54,998
# 50    58,650

# %%
# # Show initial academic DataFrame
# academic_df

# %%
# Reduce size of salary_df to only have state and year
salary_data = {'us_state':salary_df['State'],
              'salary':salary_df['2016-17.1']}
salary_df = pd.DataFrame(salary_data)

# %%
# Rename Jurisdiction to State in academic_df
academic_data = {'us_state':academic_df['Jurisdiction'],
                'at_or_above_basic':academic_df['AB'],
                'at_or_above_proficient':academic_df['AP']}
academic_df = pd.DataFrame(academic_data)

# %%
# Show salary_df after updates
salary_df['salary']=salary_df['salary'].str.replace(',','')
salary_df['us_state'] = salary_df.copy()['us_state'].str.strip()
salary_df
# Out:
#                 us_state salary
# 0                Alabama  48868
# 1                 Alaska  68138
# 2                Arizona  47403
# 3               Arkansas  48616
# 4             California  78711
# 5               Colorado  46506
# 6            Connecticut  72561
# 7               Delaware  60214
# 8   District of Columbia  76131
# 9                Florida  49407
# 10               Georgia  54602
# 11                Hawaii  57674
# 12                 Idaho  47504
# 13              Illinois  61602
# 14               Indiana  50554
# 15                  Iowa  55443
# 16                Kansas  47984
# 17              Kentucky  52339
# 18             Louisiana  50000
# 19                 Maine  51077
# 20              Maryland  66961
# 21         Massachusetts  77804
# 22              Michigan  62200
# 23             Minnesota  57346
# 24           Mississippi  42925
# 25              Missouri  48293
# 26               Montana  51422
# 27              Nebraska  52338
# 28                Nevada  57376
# 29         New Hampshire  57253
# 30            New Jersey  69623
# 31            New Mexico  47500
# 32              New York  79637
# 33        North Carolina  49837
# 34          North Dakota  51618
# 35                  Ohio  57000
# 36              Oklahoma  45245
# 37                Oregon  61631
# 38          Pennsylvania  65863
# 39          Rhode Island  66477
# 40        South Carolina  48598
# 41          South Dakota  42668
# 42             Tennessee  48456
# 43                 Texas  52575
# 44                  Utah  47244
# 45               Vermont  60187
# 46              Virginia  51049
# 47            Washington  54147
# 48         West Virginia  45701
# 49             Wisconsin  54998
# 50               Wyoming  58650

# %%
# show academic_df after updates
performances_df= academic_df.drop([53,1])
performancer_df= performances_df.drop([2,2])
performance_df= performancer_df.drop([30,3])
performance_df
# Out:
#                 us_state  at_or_above_basic at_or_above_proficient
# 0          Massachusetts                 87                     53
# 4             New Jersey                 87                     50
# 5                Wyoming                 89                     51
# 6                Indiana                 86                     48
# 7                Florida                 88                     48
# 8               Nebraska                 85                     49
# 9          New Hampshire                 85                     48
# 10          North Dakota                 85                     46
# 11                  Iowa                 83                     46
# 12                  Utah                 81                     45
# 13            Washington                 80                     42
# 14          Pennsylvania                 80                     44
# 15          South Dakota                 83                     43
# 16                Kansas                 82                     42
# 17        North Carolina                 81                     42
# 18                 Texas                 82                     41
# 19                  Ohio                 81                     41
# 20               Vermont                 81                     42
# 21               Montana                 83                     41
# 22              Colorado                 80                     42
# 23              Maryland                 78                     42
# 24             Wisconsin                 79                     42
# 25                 Idaho                 81                     40
# 26                 Maine                 81                     40
# 27              Missouri                 79                     40
# 28           Connecticut                 79                     40
# 29              Kentucky                 80                     40
# 31              Illinois                 76                     39
# 32                Hawaii                 79                     38
# 33          Rhode Island                 79                     39
# 34              Oklahoma                 80                     35
# 35             Tennessee                 77                     36
# 36               Georgia                 77                     35
# 37              Delaware                 77                     36
# 38         West Virginia                 78                     35
# 39              Michigan                 75                     36
# 40              New York                 76                     35
# 41           Mississippi                 77                     31
# 42               Arizona                 73                     34
# 43        South Carolina                 75                     32
# 44              Arkansas                 75                     33
# 45                Oregon                 73                     33
# 46            California                 71                     31
# 47               Alabama                 73                     31
# 48                Nevada                 73                     31
# 49  District of Columbia                 69                     32
# 50                Alaska                 71                     32
# 51            New Mexico                 69                     27
# 52             Louisiana                 71                     27

# %%
# Merge DataFrames for all states that match
final_data = {'us_state':salary_df['us_state'],
              'salary':salary_df['salary'],
              'at_or_above_basic':academic_df['at_or_above_basic'],
              'at_or_above_proficient':academic_df['at_or_above_proficient']
             }
final_df = pd.DataFrame(final_data)

# %%
# Drop NaN values
final_df = final_df[final_df['us_state'].notna()]

# %%
# Display final df
final_df.sort_values(by=['us_state'], inplace=True, ascending=False)
final_df['at_or_above_proficient'] = pd.to_numeric(final_df['at_or_above_proficient'])
final_df_2 = final_df
final_df
# Out:
#                 us_state salary  at_or_above_basic  at_or_above_proficient
# 50               Wyoming  58650                 71                      32
# 49             Wisconsin  54998                 69                      32
# 48         West Virginia  45701                 73                      31
# 47            Washington  54147                 73                      31
# 46              Virginia  51049                 71                      31
# 45               Vermont  60187                 73                      33
# 44                  Utah  47244                 75                      33
# 43                 Texas  52575                 75                      32
# 42             Tennessee  48456                 73                      34
# 41          South Dakota  42668                 77                      31
# 40        South Carolina  48598                 76                      35
# 39          Rhode Island  66477                 75                      36
# 38          Pennsylvania  65863                 78                      35
# 37                Oregon  61631                 77                      36
# 36              Oklahoma  45245                 77                      35
# 35                  Ohio  57000                 77                      36
# 34          North Dakota  51618                 80                      35
# 33        North Carolina  49837                 79                      39
# 32              New York  79637                 79                      38
# 31            New Mexico  47500                 76                      39
# 30            New Jersey  69623                 79                      40
# 29         New Hampshire  57253                 80                      40
# 28                Nevada  57376                 79                      40
# 27              Nebraska  52338                 79                      40
# 26               Montana  51422                 81                      40
# 25              Missouri  48293                 81                      40
# 24           Mississippi  42925                 79                      42
# 23             Minnesota  57346                 78                      42
# 22              Michigan  62200                 80                      42
# 21         Massachusetts  77804                 83                      41
# 20              Maryland  66961                 81                      42
# 19                 Maine  51077                 81                      41
# 18             Louisiana  50000                 82                      41
# 17              Kentucky  52339                 81                      42
# 16                Kansas  47984                 82                      42
# 15                  Iowa  55443                 83                      43
# 14               Indiana  50554                 80                      44
# 13              Illinois  61602                 80                      42
# 12                 Idaho  47504                 81                      45
# 11                Hawaii  57674                 83                      46
# 10               Georgia  54602                 85                      46
# 9                Florida  49407                 85                      48
# 8   District of Columbia  76131                 85                      49
# 7               Delaware  60214                 88                      48
# 6            Connecticut  72561                 86                      48
# 5               Colorado  46506                 89                      51
# 4             California  78711                 87                      50
# 3               Arkansas  48616                 87                      50
# 2                Arizona  47403                 91                      51
# 1                 Alaska  68138                 86                      53
# 0                Alabama  48868                 87                      53

# %%
# Create Scatterplot
final_df.sort_values(by=['salary'], inplace=True, ascending=True)
plot = final_df.plot.scatter(x = 'salary', y = 'at_or_above_basic', rot=80, figsize = (10,10))
fig = plot.get_figure()
fig.savefig("output.png")

# %%
# Create other Scatterplot
final_df_2.sort_values(by=['salary'], inplace=True, ascending=True)
plot2 = final_df_2.plot.scatter(x = 'salary', y = 'at_or_above_proficient', rot=80, figsize = (10,10))
fig2 = plot2.get_figure()
fig2.savefig("output2.png")

# %%
connection_string = "postgres:0217@localhost:5432/Student Performance"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()

# %%
salary_df.to_sql(name='salary', con=engine, if_exists='append', index=False)

# %%
performance_df.to_sql(name='performance', con=engine, if_exists='append', index=False)
